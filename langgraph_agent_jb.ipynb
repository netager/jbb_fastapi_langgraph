# %%
import os
import json
from typing import List, Annotated, AsyncGenerator
from typing_extensions import TypedDict
from urllib.parse import urlencode

from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langchain_openai import ChatOpenAI
from langchain_ollama import ChatOllama, OllamaEmbeddings
from langchain_teddynote.messages import messages_to_history
from langchain_teddynote.tools.tavily import TavilySearch
from langchain_teddynote.evaluator import GroundednessChecker
from langgraph.checkpoint.memory import MemorySaver

from rag.utils import format_docs
from rag.pdf import PDFRetrievalChain

# %%
from dotenv import load_dotenv
load_dotenv()

from langchain_teddynote import logging
logging.langsmith("CH17-LangGraph-Structures")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# CH17-LangGraph-Structures

# %%
# PDF 문서를 로드합니다.
# pdf = PDFRetrievalChain(["data/SPRI_AI_Brief_2023년12월호_F.pdf"]).create_chain()
pdf = PDFRetrievalChain().create_chain()

# retriever와 chain을 생성합니다.
pdf_retriever = pdf.retriever
pdf_chain = pdf.chain

# # Obtém a chave da API do ambiente
# api_key = os.getenv("OPENAI_API_KEY")

# %%
def print_state(state, func_name) -> None:
    print(f"- [{func_name}]-------------------------------------")
    print(f"question: {state['question']}")
    # print(f"context: {type(state['context'])}, {len(state['context'])}, {state['context']}")

    if state['context']:
        for context in state['context']:
            # print(f"context: {context['page_context']}")
            print(f"context: {context.metadata['source']}")
    else:
        print(f"context: {state['context']}")


    # print(f"answer: {state['answer'][:20]}")
    print(f"messages: {state['messages'][-1]}")
    print(f"relevance: {state['relevance']}")
    print("--------------------------------------")

# %%
class State(TypedDict):
    question: Annotated[str, "Question"]  # 질문(누적되는 list)
    context: Annotated[list, "Context"]  # 문서의 검색 결과
    answer: Annotated[str, "Answer"]  # 답변
    messages: Annotated[list, add_messages]  # 메시지(누적되는 list)
    relevance: Annotated[str, "Relevance"]  # 관련성



# 문서 검색 노드
def retrieve_document(state: State) -> State:
    
    print_state(state, 'retrieve_document')

    # print(f"[langgraph_agent_jb.py] state : {state['messages']}")        

    # 질문을 상태에서 가져옵니다.
    latest_question = state["question"]

    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    retrieved_docs = pdf_retriever.invoke(latest_question)
    # print(f'[langgraph_agent_jp][retrieve_document] {latest_question}')
    # print('-' * 60)
    # print(f'[langgraph_agent_jp][retrieve_document] {retrieved_docs}')   # TODO: Delete

    # 검색된 문서를 형식화합니다.(프롬프트 입력으로 넣어주기 위함)
    # retrieved_docs = format_docs(retrieved_docs)

    # 검색된 문서를 context 키에 저장합니다.
    return State(context=retrieved_docs)

        
def llm_answer(state: State) -> State:
    print_state(state, 'llm_answer')

    latest_question = state["question"]
    context = format_docs(state["context"])
    # context = state["context"]

    # print(f'[langgraph_agent_jp][llm_answer()] <{latest_question}>{type(context)}')
    # print(f'[langgraph_agent_jp][llm_answer()] context: {context}')

    # last_question = "정보보호위원회 위원에 대해 알려줘."
    
    response = pdf_chain.invoke(
        {
            "question": latest_question,
            "context": context,
            # "chat_history": messages_to_history(state["messages"]),
            "chat_history": []
        }
    )

    search_results = state['context']
    # print(f"[langgraph_agent_jb][llm_answer()] search_results: {search_results}")

    # if not search_results:
    #     logger.warning("No relevant documents found in search results.")
            
    linked_docs = []
    base_url = "https://jabis.jbbank.co.kr/jabis_pdf_view"
    
    for search_result in search_results:
        # if search_result[1] < 0.8:  # relevance threshold
        params = {
            "source": search_result.metadata["source"],
            "title": search_result.metadata["title"],
            "page": search_result.metadata["page"] + 1,
        }
        url_with_params = base_url + "?" + urlencode(params)
        
        linked_docs.append(
            f"👉 [{params['title']}]({url_with_params}) [pages]: {params['page']}"
        )

    # print(f"[langgraph_agent_jb][llm_answer()] linked_docs: {linked_docs}")
       
    response = response + "\n\n 📖 관련 문서 보기\n\n" + "\n\n".join(linked_docs)

    print(f"response: {response}")
    # 생성된 답변, (유저의 질문, 답변) 메시지를 상태에 저장합니다.
    return {
        "answer": response,
        "messages": [("assistant", response)]
    }

    # return {
    #     "answer": response,
    #     "messages": [("user", latest_question), ("assistant", response)]
    # }

    # return {"messages": [response]}        
    # return {"messages": [llm.invoke(state["messages"])]}

# 그래프 정의
graph_builder = StateGraph(State)

# 노드 정의
graph_builder.add_node("retrieve", retrieve_document)
graph_builder.add_node("llm_answer", llm_answer)

# 엣지 정의
graph_builder.add_edge(START, "retrieve")
graph_builder.add_edge("retrieve", "llm_answer")
graph_builder.add_edge("llm_answer", END)

# 체크포인터 설정
memory = MemorySaver()

# 컴파일
graph = graph_builder.compile()

# %%
retrieve_document(inputs)
# Out:
# context: []
# - [retrieve_document]-------------------------------------
# question: 정보보호위원회 위원에 대해 알려줘.
# context: []
# context: []
# messages: ('human', '정보보호위원회 위원에 대해 알려줘.')
# relevance:
# --------------------------------------
# {'context': [Document(id='0606d6c6-0749-488f-860a-f5139660aa43', metadata={'title': '(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2]', 'source': '../rag_data/jbb/규정/(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2].pdf', 'page': 0}, page_content='정보보호위원회 지침 D2010 - 1 -정보보호위원회 지침 소관부서 : 정보보호부 제 1 조 (목적) 이 지침은 ｢전자금융감독규정 ｣에 따라 정보보호위원회 (이하 “위원회 ”라 한다) 의 운영에 필요한 사항을 정함으로써 정보보호의 효율적 추진을 목적으로 한다.\n제 2 조 (구성) ① 위원회의 위원은 다음과 같이 구성한다 .\n1. 위원장 : 정보보호최고책임자 (CISO) 2. 부위원장 : 정보보호 부서장 3. 위원 : IT부서장 , 디지털 부서장 , 준법 부서장 4. 위촉위원 : 심의사항 관련부서 담당본부장 및 부, 실, 팀장 중에서 위원장이 선임하는  위원 5. 간사 : 정보보호 부서장 ② 위원회의 간사는 회의의 준비, 심의안건의 정리, 의사록 작성, 기타 제반 사무를 처리한 다.\n제 3 조 (위원장의 직무) ① 위원장은 위원회를 대표하며 위원회의 업무를 통할한다 .\n\n문서 : 전북은행 (D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2]'),
#   Document(id='70793bd5-e400-4a21-8e41-0c23d4e10826', metadata={'source': '../rag_data/jbb/규정/(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2].pdf', 'page': 1, 'title': '(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2]'}, page_content='정보보호위원회 지침 D2010 - 2 -5. 기타 위원장이 필요하다고 인정하는 사항 제 6 조 (의결 방법) ① 위원회의 의결은 위원 3분의 2이상 출석으로 성립하고 출석 위원 3분 의2 이상 찬성으로 결의한다 . 다만, 가부동수일 때에는 위원장이 결정한다 .\n② 긴급을 요하거나 기타 위원장이 인정하는 경우에는 위원회 소집을 아니하고 서면으로  의결을 할 수 있다.\n제 7 조 (의사록 ) 위원회는 의사록을 작성하여 참석위원의 서명을 받은 후 주관부서에 비치  보관한다 .\n제 8 조 (위반자의 처리) ① 전산보안사고 및 전산보안관련 규정 위반사안의 사실 확인 등을  위하여 검사가 필요하다고 판단되는 경우 감사부서에 검사를 의뢰할 수 있다. (2014. 11. 2 0 신설) ② 전산보안사고 및 전산보안관련 규정 위반자의 처리는 다음 각 호를 따른다 . (2014. 11.  20 신설\n\n문서 : 전북은행 (D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2]'),
#   Document(id='a75d9744-f332-4a86-bd11-96c33418e252', metadata={'title': '(M2005) 정보보호조직 관리 지침 [개정(1) 2020. 8.24]', 'source': '../rag_data/jbb/규정/(M2005) 정보보호조직 관리 지침 [개정(1) 2020. 8.24].pdf', 'page': 2}, page_content='제 13 조 (정보보호 실무협의체의 구성) ① 정보보호 업무의 기획, 실행, 평가 및 개선에 관한  실무적인 사항을 심의 조정하기 위한 정보보호 실무협의체를 구성한다 .\n② 협의체 의장은 정보보호 책임자가 담당하며 간사는 정보보호 담당자가 된다.\n③ 협의체 위원은 의장이 지정한 자로 구성한다 .\n제 14 조 (정보보호 실무협의체의 임무) 정보보호 실무협의체는 정보보호 관련 규정 및 지침 의 제･개정 등 정보보호에 관한 제반사항 협의 필요 시 심의 조정을 한다.\n제 15 조 (정보보호 실무협의체의 운영) ① 정보보호 책임자는 협의체 개최사유가 발생할 경 우 협의체를 소집하고 회의를 주재한다 .  ② 협의체의 부의할 안건은 간사가 작성하여 정보보호 책임자에게 제출하고 협의체 소집 1 일 전까지 각 위원에게 송부하여야 한다.\n제 6 장  기타 보안조직 제 16 조 (침해사고 대응조직 ) ① 정보보호최고책임자는 침해사고 발생에 따른 침해사고 대응\n\n문서 : 전북은행 (M2005) 정보보호조직 관리 지침 [개정(1) 2020. 8.24]')]}

# %%
question = "정보보호위원회 위원에 대해 알려줘."
inputs = {
        "question": question,
        "context": [],
        "answer": "",
        "messages": [("human", question)],
        "relevance": "",
}

# %%
from langchain_core.messages import HumanMessage

# 사용자의 메시지를 딕셔너리 형태로 입력 데이터 구성
          

# stream_mode="messages" 를 통한 스트리밍 처리
for chunk_msg, metadata in graph.stream(inputs, stream_mode="messages"):
    # HumanMessage 가 아닌 최종 노드의 유효한 컨텐츠만 출력 처리
    if (
        chunk_msg.content
        and not isinstance(chunk_msg, HumanMessage)
        and metadata["langgraph_node"] == "llm_answer"
    ):
        print(chunk_msg.content, end="", flush=True)
# Out:
# context: []
# - [retrieve_document]-------------------------------------
# question: 정보보호위원회 위원에 대해 알려줘.
# context: []
# context: []
# messages: content='정보보호위원회 위원에 대해 알려줘.' additional_kwargs={} response_metadata={} id='f6110153-8372-47ca-8ae0-ff47d49bedd3'
# relevance:
# --------------------------------------
# - [llm_answer]-------------------------------------
# question: 정보보호위원회 위원에 대해 알려줘.
# context: [Document(id='0606d6c6-0749-488f-860a-f5139660aa43', metadata={'page': 0, 'source': '../rag_data/jbb/규정/(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2].pdf', 'title': '(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2]'}, page_content='정보보호위원회 지침 D2010 - 1 -정보보호위원회 지침 소관부서 : 정보보호부 제 1 조 (목적) 이 지침은 ｢전자금융감독규정 ｣에 따라 정보보호위원회 (이하 “위원회 ”라 한다) 의 운영에 필요한 사항을 정함으로써 정보보호의 효율적 추진을 목적으로 한다.\n제 2 조 (구성) ① 위원회의 위원은 다음과 같이 구성한다 .\n1. 위원장 : 정보보호최고책임자 (CISO) 2. 부위원장 : 정보보호 부서장 3. 위원 : IT부서장 , 디지털 부서장 , 준법 부서장 4. 위촉위원 : 심의사항 관련부서 담당본부장 및 부, 실, 팀장 중에서 위원장이 선임하는  위원 5. 간사 : 정보보호 부서장 ② 위원회의 간사는 회의의 준비, 심의안건의 정리, 의사록 작성, 기타 제반 사무를 처리한 다.\n제 3 조 (위원장의 직무) ① 위원장은 위원회를 대표하며 위원회의 업무를 통할한다 .\n\n문서 : 전북은행 (D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2]'), Document(id='70793bd5-e400-4a21-8e41-0c23d4e10826', metadata={'page': 1, 'title': '(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2]', 'source': '../rag_data/jbb/규정/(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2].pdf'}, page_content='정보보호위원회 지침 D2010 - 2 -5. 기타 위원장이 필요하다고 인정하는 사항 제 6 조 (의결 방법) ① 위원회의 의결은 위원 3분의 2이상 출석으로 성립하고 출석 위원 3분 의2 이상 찬성으로 결의한다 . 다만, 가부동수일 때에는 위원장이 결정한다 .\n② 긴급을 요하거나 기타 위원장이 인정하는 경우에는 위원회 소집을 아니하고 서면으로  의결을 할 수 있다.\n제 7 조 (의사록 ) 위원회는 의사록을 작성하여 참석위원의 서명을 받은 후 주관부서에 비치  보관한다 .\n제 8 조 (위반자의 처리) ① 전산보안사고 및 전산보안관련 규정 위반사안의 사실 확인 등을  위하여 검사가 필요하다고 판단되는 경우 감사부서에 검사를 의뢰할 수 있다. (2014. 11. 2 0 신설) ② 전산보안사고 및 전산보안관련 규정 위반자의 처리는 다음 각 호를 따른다 . (2014. 11.  20 신설\n\n문서 : 전북은행 (D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2]'), Document(id='a75d9744-f332-4a86-bd11-96c33418e252', metadata={'source': '../rag_data/jbb/규정/(M2005) 정보보호조직 관리 지침 [개정(1) 2020. 8.24].pdf', 'title': '(M2005) 정보보호조직 관리 지침 [개정(1) 2020. 8.24]', 'page': 2}, page_content='제 13 조 (정보보호 실무협의체의 구성) ① 정보보호 업무의 기획, 실행, 평가 및 개선에 관한  실무적인 사항을 심의 조정하기 위한 정보보호 실무협의체를 구성한다 .\n② 협의체 의장은 정보보호 책임자가 담당하며 간사는 정보보호 담당자가 된다.\n③ 협의체 위원은 의장이 지정한 자로 구성한다 .\n제 14 조 (정보보호 실무협의체의 임무) 정보보호 실무협의체는 정보보호 관련 규정 및 지침 의 제･개정 등 정보보호에 관한 제반사항 협의 필요 시 심의 조정을 한다.\n제 15 조 (정보보호 실무협의체의 운영) ① 정보보호 책임자는 협의체 개최사유가 발생할 경 우 협의체를 소집하고 회의를 주재한다 .  ② 협의체의 부의할 안건은 간사가 작성하여 정보보호 책임자에게 제출하고 협의체 소집 1 일 전까지 각 위원에게 송부하여야 한다.\n제 6 장  기타 보안조직 제 16 조 (침해사고 대응조직 ) ① 정보보호최고책임자는 침해사고 발생에 따른 침해사고 대응\n\n문서 : 전북은행 (M2005) 정보보호조직 관리 지침 [개정(1) 2020. 8.24]')]
# context: ../rag_data/jbb/규정/(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2].pdf
# context: ../rag_data/jbb/규정/(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2].pdf
# context: ../rag_data/jbb/규정/(M2005) 정보보호조직 관리 지침 [개정(1) 2020. 8.24].pdf
# messages: content='정보보호위원회 위원에 대해 알려줘.' additional_kwargs={} response_metadata={} id='f6110153-8372-47ca-8ae0-ff47d49bedd3'
# relevance:
# --------------------------------------
# 전북은행의 정보보호위원회 구성에 대해 설명드리겠습니다.
#
# **정보보호위원회 구성 (D2010 지침)**
#
# *   **위원장:** 정보보호최고책임자 (CISO)
# *   **부위원장:** 정보보호 부서장
# *   **위원:** IT부서장, 디지털 부서장, 준법 부서장
# *   **위촉위원:** 심의사항 관련 부서 담당 본부장 및 부, 실, 팀장 중에서 위원장이 선임
# *   **간사:** 정보보호 부서장
#
# **간사의 역할:** 회의 준비, 심의 안건 정리, 의사록 작성, 기타 제반 사무 처리
#
# **참고:** 위원회의 의결은 위원 3분의 2 이상 출석하고 출석 위원 3분의 2 이상 찬성으로 결정됩니다. 가부동수일 경우 위원장이 결정합니다. (제6조)[langgraph_agent_jb][llm_answer()] search_results: [Document(id='0606d6c6-0749-488f-860a-f5139660aa43', metadata={'page': 0, 'source': '../rag_data/jbb/규정/(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2].pdf', 'title': '(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2]'}, page_content='정보보호위원회 지침 D2010 - 1 -정보보호위원회 지침 소관부서 : 정보보호부 제 1 조 (목적) 이 지침은 ｢전자금융감독규정 ｣에 따라 정보보호위원회 (이하 “위원회 ”라 한다) 의 운영에 필요한 사항을 정함으로써 정보보호의 효율적 추진을 목적으로 한다.\n제 2 조 (구성) ① 위원회의 위원은 다음과 같이 구성한다 .\n1. 위원장 : 정보보호최고책임자 (CISO) 2. 부위원장 : 정보보호 부서장 3. 위원 : IT부서장 , 디지털 부서장 , 준법 부서장 4. 위촉위원 : 심의사항 관련부서 담당본부장 및 부, 실, 팀장 중에서 위원장이 선임하는  위원 5. 간사 : 정보보호 부서장 ② 위원회의 간사는 회의의 준비, 심의안건의 정리, 의사록 작성, 기타 제반 사무를 처리한 다.\n제 3 조 (위원장의 직무) ① 위원장은 위원회를 대표하며 위원회의 업무를 통할한다 .\n\n문서 : 전북은행 (D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2]'), Document(id='70793bd5-e400-4a21-8e41-0c23d4e10826', metadata={'page': 1, 'title': '(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2]', 'source': '../rag_data/jbb/규정/(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2].pdf'}, page_content='정보보호위원회 지침 D2010 - 2 -5. 기타 위원장이 필요하다고 인정하는 사항 제 6 조 (의결 방법) ① 위원회의 의결은 위원 3분의 2이상 출석으로 성립하고 출석 위원 3분 의2 이상 찬성으로 결의한다 . 다만, 가부동수일 때에는 위원장이 결정한다 .\n② 긴급을 요하거나 기타 위원장이 인정하는 경우에는 위원회 소집을 아니하고 서면으로  의결을 할 수 있다.\n제 7 조 (의사록 ) 위원회는 의사록을 작성하여 참석위원의 서명을 받은 후 주관부서에 비치  보관한다 .\n제 8 조 (위반자의 처리) ① 전산보안사고 및 전산보안관련 규정 위반사안의 사실 확인 등을  위하여 검사가 필요하다고 판단되는 경우 감사부서에 검사를 의뢰할 수 있다. (2014. 11. 2 0 신설) ② 전산보안사고 및 전산보안관련 규정 위반자의 처리는 다음 각 호를 따른다 . (2014. 11.  20 신설\n\n문서 : 전북은행 (D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2]'), Document(id='a75d9744-f332-4a86-bd11-96c33418e252', metadata={'source': '../rag_data/jbb/규정/(M2005) 정보보호조직 관리 지침 [개정(1) 2020. 8.24].pdf', 'title': '(M2005) 정보보호조직 관리 지침 [개정(1) 2020. 8.24]', 'page': 2}, page_content='제 13 조 (정보보호 실무협의체의 구성) ① 정보보호 업무의 기획, 실행, 평가 및 개선에 관한  실무적인 사항을 심의 조정하기 위한 정보보호 실무협의체를 구성한다 .\n② 협의체 의장은 정보보호 책임자가 담당하며 간사는 정보보호 담당자가 된다.\n③ 협의체 위원은 의장이 지정한 자로 구성한다 .\n제 14 조 (정보보호 실무협의체의 임무) 정보보호 실무협의체는 정보보호 관련 규정 및 지침 의 제･개정 등 정보보호에 관한 제반사항 협의 필요 시 심의 조정을 한다.\n제 15 조 (정보보호 실무협의체의 운영) ① 정보보호 책임자는 협의체 개최사유가 발생할 경 우 협의체를 소집하고 회의를 주재한다 .  ② 협의체의 부의할 안건은 간사가 작성하여 정보보호 책임자에게 제출하고 협의체 소집 1 일 전까지 각 위원에게 송부하여야 한다.\n제 6 장  기타 보안조직 제 16 조 (침해사고 대응조직 ) ① 정보보호최고책임자는 침해사고 발생에 따른 침해사고 대응\n\n문서 : 전북은행 (M2005) 정보보호조직 관리 지침 [개정(1) 2020. 8.24]')]
# response: 전북은행의 정보보호위원회 구성에 대해 설명드리겠습니다.
#
# **정보보호위원회 구성 (D2010 지침)**
#
# *   **위원장:** 정보보호최고책임자 (CISO)
# *   **부위원장:** 정보보호 부서장
# *   **위원:** IT부서장, 디지털 부서장, 준법 부서장
# *   **위촉위원:** 심의사항 관련 부서 담당 본부장 및 부, 실, 팀장 중에서 위원장이 선임
# *   **간사:** 정보보호 부서장
#
# **간사의 역할:** 회의 준비, 심의 안건 정리, 의사록 작성, 기타 제반 사무 처리
#
# **참고:** 위원회의 의결은 위원 3분의 2 이상 출석하고 출석 위원 3분의 2 이상 찬성으로 결정됩니다. 가부동수일 경우 위원장이 결정합니다. (제6조)
#
#  📖 관련 문서 보기
#
# 👉 [(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2]](https://jabis.jbbank.co.kr/jabis_pdf_view?source=..%2Frag_data%2Fjbb%2F%EA%B7%9C%EC%A0%95%2F%28D2010%29+%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%EC%9C%84%EC%9B%90%ED%9A%8C+%EC%A7%80%EC%B9%A8+%5B%EA%B0%9C%EC%A0%95%283%29+2018.+4.+2%5D.pdf&title=%28D2010%29+%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%EC%9C%84%EC%9B%90%ED%9A%8C+%EC%A7%80%EC%B9%A8+%5B%EA%B0%9C%EC%A0%95%283%29+2018.+4.+2%5D&page=1) [pages]: 1
#
# 👉 [(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2]](https://jabis.jbbank.co.kr/jabis_pdf_view?source=..%2Frag_data%2Fjbb%2F%EA%B7%9C%EC%A0%95%2F%28D2010%29+%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%EC%9C%84%EC%9B%90%ED%9A%8C+%EC%A7%80%EC%B9%A8+%5B%EA%B0%9C%EC%A0%95%283%29+2018.+4.+2%5D.pdf&title=%28D2010%29+%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%EC%9C%84%EC%9B%90%ED%9A%8C+%EC%A7%80%EC%B9%A8+%5B%EA%B0%9C%EC%A0%95%283%29+2018.+4.+2%5D&page=2) [pages]: 2
#
# 👉 [(M2005) 정보보호조직 관리 지침 [개정(1) 2020. 8.24]](https://jabis.jbbank.co.kr/jabis_pdf_view?source=..%2Frag_data%2Fjbb%2F%EA%B7%9C%EC%A0%95%2F%28M2005%29+%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%EC%A1%B0%EC%A7%81+%EA%B4%80%EB%A6%AC+%EC%A7%80%EC%B9%A8+%5B%EA%B0%9C%EC%A0%95%281%29+2020.+8.24%5D.pdf&title=%28M2005%29+%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%EC%A1%B0%EC%A7%81+%EA%B4%80%EB%A6%AC+%EC%A7%80%EC%B9%A8+%5B%EA%B0%9C%EC%A0%95%281%29+2020.+8.24%5D&page=3) [pages]: 3

# %%
from langchain_core.messages import (
    convert_to_openai_messages,
    message_chunk_to_message)
from fastapi.responses import StreamingResponse

def stream(inputs: State):
    def event_stream():
        try:
            # print(f"\nReceived inputs: {inputs}\n")
            # async for event in graph.astream(input=inputs, stream_mode="messages"):
            for event in graph.astream(input=inputs, stream_mode="messages"):
                print(f"\nReceived event: {event}\n")
                # get first element of tuple
                print(f"\nReceived event[0]['content']: {event[0]['content']}\n")
            
                message = message_chunk_to_message(event[0])
                print(f"\nConverted event: {message}\n")
                yield convert_to_openai_messages(message)['content']
        except Exception as e:
            print(f"An error occurred: {e}")

    return StreamingResponse(event_stream(), media_type="application/json")

# %%
stream(inputs)

# %%
for event in graph.stream(input=inputs, stream_mode="messages"):
    print(f"\nReceived event: {event}\n")
    # get first element of tuple
    # print(f"\nReceived event[0]['content']: {event[0]['content']}\n")

    message = message_chunk_to_message(event[0])
    print(f"\nConverted event: {message}\n")
# Out:
# - [retrieve_document]-------------------------------------
# question: 정보보호위원회 위원에 대해 알려줘.
# context: []
# messages: content='정보보호위원회 위원에 대해 알려줘.' additional_kwargs={} response_metadata={} id='03a43476-920f-4ceb-8e9f-79b7ef0d7b41'
# relevance:
# --------------------------------------
# - [llm_answer]-------------------------------------
# question: 정보보호위원회 위원에 대해 알려줘.
# context: ../rag_data/jbb/규정/(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2].pdf
# context: ../rag_data/jbb/규정/(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2].pdf
# context: ../rag_data/jbb/규정/(M2005) 정보보호조직 관리 지침 [개정(1) 2020. 8.24].pdf
# messages: content='정보보호위원회 위원에 대해 알려줘.' additional_kwargs={} response_metadata={} id='03a43476-920f-4ceb-8e9f-79b7ef0d7b41'
# relevance:
# --------------------------------------
#
# Received event: (AIMessageChunk(content='전', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='전' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='북', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='북' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='은행', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='은행' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='의', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='의' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=' 정보', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=' 정보' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='보', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='보' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='호', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='호' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='위원회', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='위원회' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=' 구성', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=' 구성' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='에', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='에' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=' 대해', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=' 대해' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=' 설명', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=' 설명' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='드리', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='드리' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='겠습니다', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='겠습니다' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='.' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='\n\n', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='\n\n' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='**' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='정보', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='정보' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='보', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='보' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='호', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='호' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='위원회', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='위원회' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=' 구성', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=' 구성' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=' (' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='D', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='D' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='2', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='2' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='0', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='0' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='1', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='1' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='0', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='0' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=' 지', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=' 지' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='침', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='침' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=')**', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=')**' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='\n\n', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='\n\n' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='*', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='*' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='   ', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='   ' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='**' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='위원', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='위원' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='장', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='장' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=':**', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=':**' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=' 정보', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=' 정보' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='보', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='보' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='호', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='호' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='최', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='최' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='고', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='고' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='책', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='책' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='임', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='임' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='자', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='자' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=' (' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='C', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='C' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='ISO', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='ISO' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=')', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=')' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='\n' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='*', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='*' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='   ', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='   ' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='**' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='부', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='부' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='위원', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='위원' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='장', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='장' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=':**', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=':**' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=' 정보', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=' 정보' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='보', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='보' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='호', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='호' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=' 부', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=' 부' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='서', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='서' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='장', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='장' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='\n', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='\n' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='*', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='*' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='   ', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='   ' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='**', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='**' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='위원', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='위원' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=':**', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=':**' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=' IT', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# ...
#
#
# Converted event: content=' 결정' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='됩니다', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='됩니다' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='.' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=' 가', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=' 가' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='부', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='부' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='동', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='동' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='수', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='수' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='일', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='일' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=' 경우', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=' 경우' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=' 위', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=' 위' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='원', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='원' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='장이', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='장이' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=' 결정', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=' 결정' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='합니다', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='합니다' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='.', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='.' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=' (', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=' (' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='제', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='제' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='6', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='6' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='조', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='조' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content=')', additional_kwargs={}, response_metadata={}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content=')' additional_kwargs={} response_metadata={} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b'
#
#
# Received event: (AIMessageChunk(content='', additional_kwargs={}, response_metadata={'model': 'gemma3:12b', 'created_at': '2025-07-01T00:26:01.554143Z', 'done': True, 'done_reason': 'stop', 'total_duration': 13458649708, 'load_duration': 41813375, 'prompt_eval_count': 1496, 'prompt_eval_duration': 8048584041, 'eval_count': 211, 'eval_duration': 5364476292, 'model_name': 'gemma3:12b'}, id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b', usage_metadata={'input_tokens': 1496, 'output_tokens': 211, 'total_tokens': 1707}), {'langgraph_step': 2, 'langgraph_node': 'llm_answer', 'langgraph_triggers': ('branch:to:llm_answer',), 'langgraph_path': ('__pregel_pull', 'llm_answer'), 'langgraph_checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'checkpoint_ns': 'llm_answer:58234424-34a3-ea70-b0cd-805f43ca55bc', 'ls_provider': 'ollama', 'ls_model_name': 'gemma3:12b', 'ls_model_type': 'chat', 'ls_temperature': 0.0})
#
#
# Converted event: content='' additional_kwargs={} response_metadata={'model': 'gemma3:12b', 'created_at': '2025-07-01T00:26:01.554143Z', 'done': True, 'done_reason': 'stop', 'total_duration': 13458649708, 'load_duration': 41813375, 'prompt_eval_count': 1496, 'prompt_eval_duration': 8048584041, 'eval_count': 211, 'eval_duration': 5364476292, 'model_name': 'gemma3:12b'} id='run--fe184092-a4a3-4f52-99a5-be0db3e5b34b' usage_metadata={'input_tokens': 1496, 'output_tokens': 211, 'total_tokens': 1707}
#
# response: 전북은행의 정보보호위원회 구성에 대해 설명드리겠습니다.
#
# **정보보호위원회 구성 (D2010 지침)**
#
# *   **위원장:** 정보보호최고책임자 (CISO)
# *   **부위원장:** 정보보호 부서장
# *   **위원:** IT부서장, 디지털 부서장, 준법 부서장
# *   **위촉위원:** 심의사항 관련 부서 담당 본부장 및 부, 실, 팀장 중에서 위원장이 선임
# *   **간사:** 정보보호 부서장
#
# **간사의 역할:** 회의 준비, 심의 안건 정리, 의사록 작성, 기타 제반 사무 처리
#
# **참고:** 위원회의 의결은 위원 3분의 2 이상 출석하고 출석 위원 3분의 2 이상 찬성으로 결정됩니다. 가부동수일 경우 위원장이 결정합니다. (제6조)
#
#  📖 관련 문서 보기
#
# 👉 [(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2]](https://jabis.jbbank.co.kr/jabis_pdf_view?source=..%2Frag_data%2Fjbb%2F%EA%B7%9C%EC%A0%95%2F%28D2010%29+%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%EC%9C%84%EC%9B%90%ED%9A%8C+%EC%A7%80%EC%B9%A8+%5B%EA%B0%9C%EC%A0%95%283%29+2018.+4.+2%5D.pdf&title=%28D2010%29+%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%EC%9C%84%EC%9B%90%ED%9A%8C+%EC%A7%80%EC%B9%A8+%5B%EA%B0%9C%EC%A0%95%283%29+2018.+4.+2%5D&page=1) [pages]: 1
#
# 👉 [(D2010) 정보보호위원회 지침 [개정(3) 2018. 4. 2]](https://jabis.jbbank.co.kr/jabis_pdf_view?source=..%2Frag_data%2Fjbb%2F%EA%B7%9C%EC%A0%95%2F%28D2010%29+%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%EC%9C%84%EC%9B%90%ED%9A%8C+%EC%A7%80%EC%B9%A8+%5B%EA%B0%9C%EC%A0%95%283%29+2018.+4.+2%5D.pdf&title=%28D2010%29+%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%EC%9C%84%EC%9B%90%ED%9A%8C+%EC%A7%80%EC%B9%A8+%5B%EA%B0%9C%EC%A0%95%283%29+2018.+4.+2%5D&page=2) [pages]: 2
#
# 👉 [(M2005) 정보보호조직 관리 지침 [개정(1) 2020. 8.24]](https://jabis.jbbank.co.kr/jabis_pdf_view?source=..%2Frag_data%2Fjbb%2F%EA%B7%9C%EC%A0%95%2F%28M2005%29+%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%EC%A1%B0%EC%A7%81+%EA%B4%80%EB%A6%AC+%EC%A7%80%EC%B9%A8+%5B%EA%B0%9C%EC%A0%95%281%29+2020.+8.24%5D.pdf&title=%28M2005%29+%EC%A0%95%EB%B3%B4%EB%B3%B4%ED%98%B8%EC%A1%B0%EC%A7%81+%EA%B4%80%EB%A6%AC+%EC%A7%80%EC%B9%A8+%5B%EA%B0%9C%EC%A0%95%281%29+2020.+8.24%5D&page=3) [pages]: 3
